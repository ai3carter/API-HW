# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 609

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cities_df = pd.DataFrame({'City': cities})
cities_df.tail()
# Out:
#           City
# 604    kendari
# 605    te anau
# 606  menomonie
# 607    bontang
# 608      kathu

# %%
random_city=cities_df.sample(n=500)
random_city.tail()
# Out:
#                   City
# 365      graaff-reinet
# 573             aktash
# 76         yellowknife
# 328  nizhniy tsasuchey
# 424        kangaatsiaq

# %%
len(random_city)
# Out:
# 500

# %%
##This is the table what they expect us to complete
random_city["Cloudiness"]= ""
random_city["Country"] = ""
random_city["Date"] = ""
random_city["Humidity"] = ""
random_city["Lat"] = ""
random_city["Lng"] = ""
random_city["Max Temp"] = ""
random_city["Wind Speed"]= ""
random_city.head()
# Out:
#            City Cloudiness Country Date Humidity Lat Lng Max Temp Wind Speed
# 147       pevek
# 107        mega
# 215  hambantota
# 394       muros
# 193     kuusamo

# %%
target_url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
##target_url="http://api.openweathermap.org/data/2.5/weather"
##params={"units":"imperial",
        ##"appid":"ccc86d264a0c0f54b4406ca8641eedaa"
       ##}

city_name=[]
cloudiness= []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed= []


city_count=1
print("Beginning Data Retrieval")
print("-----------------------------")

for city in cities:
    try:
        response=requests.get(f"{target_url}&q={city}").json()
        #response=requests.get(url,params).json()
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        
        
        city_info=response["name"]
        print(f"Processing Record {city_count} | {city_info}")
        #print(f"{target_url}&q={city}")
        city_count+=1
    except:
        print("City not found. Skipping...")
    continue


print("-----------------------------")
print("Data Retrieval Complete")      
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 | Kapaa
# Processing Record 2 | Parrita
# Processing Record 3 | Aswan
# Processing Record 4 | Hami
# Processing Record 5 | Yulara
# Processing Record 6 | Ushuaia
# Processing Record 7 | Sao Filipe
# Processing Record 8 | Dakar
# Processing Record 9 | Sitka
# Processing Record 10 | Matagami
# Processing Record 11 | Qaanaaq
# City not found. Skipping...
# Processing Record 12 | Tuktoyaktuk
# Processing Record 13 | Beringovskiy
# Processing Record 14 | Meulaboh
# Processing Record 15 | Iqaluit
# Processing Record 16 | Cabo Rojo
# Processing Record 17 | Bethel
# Processing Record 18 | Castro
# Processing Record 19 | Chuy
# Processing Record 20 | Victoria
# Processing Record 21 | Avarua
# Processing Record 22 | Butaritari
# Processing Record 23 | Zelenets
# Processing Record 24 | Hithadhoo
# Processing Record 25 | Hilo
# Processing Record 26 | Guadalupe y Calvo
# Processing Record 27 | Deputatskiy
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
data={"City":city_name,
      "Cloudiness":cloudiness,
      "Country":country,
      "Date":date, 
      "Humidity":humidity, 
      "Lat":lat, 
      "Lng":lng,
      "Max Temp":max_temp, 
      "Wind Speed":wind_speed
     }
data_df=pd.DataFrame(data)
data_df.count()
# Out:
# City          554
# Cloudiness    554
# Country       554
# Date          554
# Humidity      554
# Lat           554
# Lng           554
# Max Temp      554
# Wind Speed    554
# dtype: int64

# %%
data_df.to_csv("WorldWeatherData.csv", index=False)

# %%
data_df.head()
# Out:
#       City  Cloudiness Country        Date  Humidity    Lat     Lng  Max Temp  \
# 0    Kapaa          75      US  1567656305        70  22.08 -159.32     87.80
# 1  Parrita           0      CR  1567656306        94   9.52  -84.33     71.01
# 2    Aswan          62      EG  1567656306        29  24.09   32.90     80.59
# 3     Hami          44      CN  1567656306        11  42.84   93.51     87.22
# 4   Yulara           0      AU  1567656306        12 -25.24  130.99     84.20
#
#    Wind Speed
# 0       18.34
# 1        1.12
# 2       13.85
# 3        2.62
# 4        3.36

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(data_df["Lat"],data_df["Max Temp"], alpha = 0.85,edgecolor="black")

plt.title("City Latitude vs. Max Temperature (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig("Temperature.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(data_df["Lat"],data_df["Humidity"], alpha = 0.85,edgecolor="black")

plt.title("City Latitude vs. Humidity (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig("Humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(data_df["Lat"],data_df["Cloudiness"], alpha = 0.85,edgecolor="black")

plt.title("City Latitude vs. Cloudiness (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig("Cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(data_df["Lat"],data_df["Wind Speed"], alpha= 0.85,edgecolor="black")
plt.title("City Latitude vs. Wind Speed (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig("Wind Speed.png")
plt.show()
